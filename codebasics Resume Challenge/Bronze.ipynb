# %% [markdown]
# #first Read the file

# %%
spark

# %%
df1 = spark.read.option("header", "true").option("inferSchema", "true").csv("/Volumes/codebasics/bronze/anime_files/anime.csv")
df1.display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
df2 = spark.read.option("header", "true").option("inferSchema", "true").csv("/Volumes/codebasics/bronze/anime_files/rating.csv")
df2.display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %% [markdown]
# ##check schema

# %%
df1.printSchema()
df2.printSchema()
# Out:
# root
#  |-- anime_id: integer (nullable = true)
#  |-- name: string (nullable = true)
#  |-- genre: string (nullable = true)
#  |-- type: string (nullable = true)
#  |-- episodes: string (nullable = true)
#  |-- rating: double (nullable = true)
#  |-- members: integer (nullable = true)
#
# root
#  |-- user_id: integer (nullable = true)
#  |-- anime_id: integer (nullable = true)
#  |-- rating: integer (nullable = true)

# %% [markdown]
# #write to the Bronze layer

# %%
df1.write.mode("overwrite").format("delta").saveAsTable("codebasics.bronze.bronze_anime")

# %%
df2.write.mode("overwrite").format("delta").saveAsTable("codebasics.bronze.bronze_rating")
